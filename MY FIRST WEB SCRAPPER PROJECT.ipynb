# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# for pagination to append later to the extracted hrefs
baseurl = "https://www.motoworld.com.ph"

# %%
# to mimic human requests as much as possible
headers = {
    'User=Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36',
    'Accept-Language' : 'en-US,en;q=0.9,la;q=0.8',
    'Referer':'https://www.youtube.com/', 
       
}

# to requests html/lxml from website to scrape

#r = requests.get("https://www.motoworld.com.ph/collections/helmets?page=1")
#soup  = BeautifulSoup(r.content, "lxml")


# to extract all of the product listed on one page

#productlist = soup.find_all('div', class_="card__info-inner inline-block w-full")

#productlinks = []

# looping through the a tags from the extracted card or product listed on the page

#for card in productlist:
  #  for link in card.find_all('a', href = True):
        #print(link['href'])
       # productlinks.append(baseurl + link['href'] )


#print(len(productlinks))

# to loop through all pagitation, we need to creat a for loop 1-26 as it is 25 pages
# use the url of the 1st page as initial request as a f string to increment the number of the pages

productlinks = []

for x in range(1,26):
    
    r = requests.get(f"https://www.motoworld.com.ph/collections/helmets?page={x}")
    soup  = BeautifulSoup(r.content, "lxml")

    productlist = soup.find_all('product-card', class_="card card--product h-full card--product-contained card--no-lines relative flex")
    
  
    for card in productlist:
        for link in card.find_all('a', href = True):
            productlinks.append(baseurl + link['href'] )

#print(productlinks)

# To get product information we'll have to loop through each links (like clicking on to each products) and exact the data

#testlink = "https://www.motoworld.com.ph/collections/helmets/products/ff320-evo-mara-full-face-helmet"

#r = requests.get(testlink, headers = headers)

#soup = BeautifulSoup(r.content, "lxml")

#name = soup.find('h1', class_="product-title h5").text.strip()
#ratings = soup.find('span', class_="wc_product_review_avg_badge_countr")
#reviews = soup.find('span', class_="wc_product_review_text")
#price = soup.find('strong', class_="price__current").text.strip()
#print(name, ratings, reviews, price)

#helmet = {
#    'name' : name,
#    'ratings' : ratings,
#    'reviews' : reviews,
#    'price' : price
#}

# %%
helmet_list = []

for link in productlinks:
    
    r = requests.get(link, headers = headers)

    soup = BeautifulSoup(r.content, "lxml")

    name = soup.find('h1', class_="product-title h5").text.strip()
    price = soup.find('strong', class_="price__current").text.strip()
    try:
        ratings = soup.find('span', class_="wc_product_review_avg_badge_count").text.strip()
    except:
        rating = 'No Rating'
    try:
        reviews = soup.find('span', class_="wc_product_review_text").text.strip()
    except:
        riviews = 'No Reviews'
    
    #print(name, ratings, reviews, price)

    helmet = {
        'name' : name,
        'price' : price,
        'ratings' : ratings,
        'reviews' : reviews
        
    }
    
    helmet_list.append(helmet)
    print("Saving...!", helmet['name'])
    

# saving to pandas dataframe

df = pd.DataFrame(helmet_list)
print(df.head(20))
# Out:
# Saving...! LS2 FF320 EVO MARA FULL FACE HELMET
# Saving...! LS2 FF320 EVO MARA FULL FACE HELMET
# Saving...! LS2 FF800 STORM II POWER HELMET
# Saving...! LS2 FF800 STORM II POWER HELMET
# Saving...! NOLAN N30-4 VP INCEPTION HELMET
# Saving...! NOLAN N30-4 VP INCEPTION HELMET
# Saving...! NOLAN N90-3 REFLECTOR MODULAR HELMET
# Saving...! NOLAN N90-3 REFLECTOR MODULAR HELMET
# Saving...! NOLAN N90-3 LANEWAY MODULAR HELMET
# Saving...! NOLAN N90-3 LANEWAY MODULAR HELMET
# Saving...! NOLAN N80-8 KOSMOS HELMET
# Saving...! NOLAN N80-8 KOSMOS HELMET
# Saving...! NOLAN N80-8 METEOR HELMET
# Saving...! NOLAN N80-8 METEOR HELMET
# Saving...! SENA SPIDER ST1 MESH INTERCOM HEADSET
# Saving...! SENA SPIDER ST1 MESH INTERCOM HEADSET
# Saving...! DAINESE LINEA 01 MIPS MTB HELMET
# Saving...! DAINESE LINEA 01 MIPS MTB HELMET
# Saving...! O'NEAL 3 SERIES INTERCEPTOR V.22 HELMET
# Saving...! O'NEAL 3 SERIES INTERCEPTOR V.22 HELMET
# Saving...! O'NEAL 3 SERIES SCARZ V.22 HELMET
# Saving...! O'NEAL 3 SERIES SCARZ V.22 HELMET
# Saving...! O'NEAL 3 SERIES VERTICAL V.22 HELMET
# Saving...! O'NEAL 3 SERIES VERTICAL V.22 HELMET
# Saving...! O'NEAL SIERRA R V.22 HELMET
# Saving...! O'NEAL SIERRA R V.22 HELMET
# Saving...! O'NEAL 3 SERIES CAMO V.22 HELMET
# Saving...! O'NEAL 3 SERIES CAMO V.22 HELMET
# Saving...! O'NEAL DEFENDER RIDE MTB HELMET
# Saving...! O'NEAL DEFENDER RIDE MTB HELMET
# Saving...! O'NEAL DEFENDER GRILL MTB HELMET
# Saving...! O'NEAL DEFENDER GRILL MTB HELMET
# Saving...! O'NEAL PIKE IPX MTB HELMET
# Saving...! O'NEAL PIKE IPX MTB HELMET
# Saving...! RYO RF-2 FS-825 DECAL 4-2 HELMET
# Saving...! RYO RF-2 FS-825 DECAL 4-2 HELMET
# Saving...! O'NEAL 2SRS YOUTH RUSH HELMET
# Saving...! O'NEAL 2SRS YOUTH RUSH HELMET
# Saving...! SMK TYPHOON HELMET VISOR
# Saving...! SMK TYPHOON HELMET VISOR
# Saving...! SMK GULLWING KRESTO HELMET
# Saving...! SMK GULLWING KRESTO HELMET
# Saving...! RYO RM-1 (FS-908) DECAL 2 HELMET
# Saving...! RYO RM-1 (FS-908) DECAL 2 HELMET
# Saving...! RYO RM-1 (FS-908) DECAL 1 HELMET
# Saving...! RYO RM-1 (FS-908) DECAL 1 HELMET
# Saving...! SMK TYPHOON THORN HELMET
# Saving...! SMK TYPHOON THORN HELMET
# Saving...! 100% ACCURI 2 GOGGLES YOUTH MOORE
# Saving...! 100% ACCURI 2 GOGGLES YOUTH MOORE
# Saving...! SMK TYPHOON RD1 HELMET
# Saving...! SMK TYPHOON RD1 HELMET
# Saving...! SMK TYPHOON MONO HELMET
# Saving...! SMK TYPHOON MONO HELMET
# Saving...! AGV ORBYT VALENCIA 2003 HELMET
# Saving...! AGV ORBYT VALENCIA 2003 HELMET
# Saving...! SMK GULLWING HELMET VISOR
# Saving...! SMK GULLWING HELMET VISOR
# Saving...! LS2 FF353 RAPID STRATUS HELMET (w/ EXTRA VISOR)
# Saving...! LS2 FF353 RAPID STRATUS HELMET (w/ EXTRA VISOR)
# Saving...! LS2 FF353 RAPID HAPPY DREAMS HELMET w/ FREE SPOILER & VISOR
# Saving...! LS2 FF353 RAPID HAPPY DREAMS HELMET w/ FREE SPOILER & VISOR
# Saving...! LS2 FF353 RAPID GALE HELMET (w/ EXTRA VISOR)
# Saving...! LS2 FF353 RAPID GALE HELMET (w/ EXTRA VISOR)
# Saving...! LS2 FF353 RAPID HELMET w/ FREE SPOILER & VISOR
# Saving...! LS2 FF353 RAPID HELMET w/ FREE SPOILER & VISOR
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14476/220890591.py in <module>
#       7     soup = BeautifulSoup(r.content, "lxml")
#       8
# ----> 9     name = soup.find('h1', class_="product-title h5").text.strip()
#      10     price = soup.find('strong', class_="price__current").text.strip()
#      11     try:
#
# AttributeError: 'NoneType' object has no attribute 'text'
